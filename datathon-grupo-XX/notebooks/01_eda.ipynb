# %%
import pandas as pd

df = pd.read_csv("../data/raw/dataset.csv")

print(df.head())
print(df.info())
print(df["label"].value_counts())
print(df.isnull().sum())
df["texto_len"] = df["texto"].str.len()
print(df["texto_len"].describe())
